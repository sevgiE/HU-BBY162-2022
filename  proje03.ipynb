# %% [markdown]
# <a href="https://colab.research.google.com/github/sevgiE/HU-BBY162-2022/blob/main/%20proje03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Merhaba, mini testimize hoşgeldiniz ^^")
print("Testimizdeki önemli alanlar : ")
print("10 soru bulunmaktadır.")
print("Sorulara evet ya da hayır şeklinde cevaplar verilmesi gerekir. Aksi takdirde verdiğiniz cevap yanlış kabul edilecektir.")
print("Aldığınız puan 60 üzeri ise testten geçer, 60 altı ise testten kalırsınız. ")
print(" Herkese başarılar diliyorum :)")

sorular = ["Yarasalar memeli canlılar grubunda yer alırlar.","Atatürk 1881 yılında doğmuştur.", "Altın Ap şeklinde gösterilir","Portakal turunçgillerdendir.","Şubat ayı 29 gündür","Bitkiler fotosentez yapar.","Bihter 7 harften oluşan bir kelimedir.","Mitokondri hücresi, enerji üreten hücredir.","Kimbap bir Kore yemeğidir.","Piranalar etçildir."]
cevaplar = ["evet","evet","hayır","evet","hayır","evet","hayır","evet","evet","evet"]
puan = 0

print("1. " + sorular [0])
cevap1 = input("Cevabınız: ")
if  cevap1 == cevaplar[0]:
  print("Doğru cevap!! :)")
  puan += 10
else:
  print("Üzgünüm...Yanlış cevap. :(")
print("Puanınız :" + str(puan))

print("2. " + sorular [1])
cevap2 = input("Cevabınız: ")
if  cevap2 == cevaplar[1]:
  print("Doğru cevap!! :)")
  puan += 10
else:
  print("Üzgünüm...Yanlış cevap. :(")
print("Puanınız :" + str(puan))

print("3. " + sorular [2])
cevap3 = input("Cevabınız: ")
if  cevap3 == cevaplar[2]:
  print("Doğru cevap!! :)")
  puan += 10
else:
  print("Üzgünüm...Yanlış cevap. :(")
print("Puanınız :" + str(puan))

print("4. " + sorular [3])
cevap4 = input("Cevabınız: ")
if  cevap4 == cevaplar[3]:
  print("Doğru cevap!! :)")
  puan += 10
else:
  print("Üzgünüm...Yanlış cevap. :(")
print("Puanınız :" + str(puan))

print("5. " + sorular [4])
cevap5 = input("Cevabınız: ")
if  cevap5 == cevaplar[4]:
  print("Doğru cevap!! :)")
  puan += 10
else:
  print("Üzgünüm...Yanlış cevap. :(")
print("Puanınız :" + str(puan))

print("6. " + sorular [5])
cevap6 = input("Cevabınız: ")
if  cevap6 == cevaplar[5]:
  print("Doğru cevap!! :)")
  puan += 10
else:
  print("Üzgünüm...Yanlış cevap. :(")
print("Puanınız :" + str(puan))

print("7. " + sorular [6])
cevap7 = input("Cevabınız: ")
if  cevap7 == cevaplar[6]:
  print("Doğru cevap!! :)")
  puan += 10
else:
  print("Üzgünüm...Yanlış cevap. :(")
print("Puanınız :" + str(puan))

print("8. " + sorular [7])
cevap8 = input("Cevabınız: ")
if  cevap8 == cevaplar[7]:
  print("Doğru cevap!! :)")
  puan += 10
else:
  print("Üzgünüm...Yanlış cevap. :(")
print("Puanınız :" + str(puan))

print("9. " + sorular [8])
cevap9 = input("Cevabınız: ")
if  cevap9 == cevaplar[8]:
  print("Doğru cevap!! :)")
  puan += 10
else:
  print("Üzgünüm...Yanlış cevap. :(")
print("Puanınız :" + str(puan))

print("10. " + sorular [9])
cevap10 = input("Cevabınız: ")
if  cevap10 == cevaplar[9]:
  print("Doğru cevap!! :)")
  puan += 10
else:
  print("Üzgünüm...Yanlış cevap. :(")



if puan == 0:
  print("Maalesef 10 cevap da yanlış ve 0 cevap doğru.. Puanınız: 0")
  print("Testi geçemediniz.")
  tekrar = input("Testi tekrar denemek ister misiniz? evet/hayır")
  evet = "evet"
  hayır = "hayır"
  if tekrar == evet:
    print("Tekrardan başarılar.")
  elif tekrar == hayır:
    print("Görüşmek dileğiyle.:)")



if puan == 10:
  print("Maalesef 9 cevabınız yanlış ve 1 cevabınız doğru. Puanınız: 10")
  print("Testi geçemediniz.")
  tekrar = input("Testi tekrar denemek ister misiniz? evet/hayır")
  evet = "evet"
  hayır = "hayır"
  if tekrar == evet:
    print("Tekrardan başarılar.")
  elif tekrar == hayır:
    print("Görüşmek dileğiyle.:)")
   

if puan == 20:
  print("Maalesef 8 cevabınız yanlış ve 2 cevabınız doğru. Puanınız: 20")
  print("Testi geçemediniz.")
  tekrar = input("Testi tekrar denemek ister misiniz? evet/hayır")
  evet = "evet"
  hayır = "hayır"
  if tekrar == evet:
    print("Tekrardan başarılar.")
  elif tekrar == hayır:
    print("Görüşmek dileğiyle.:)")

if puan == 30:
  print("Maalesef 7 cevabınız yanlış ve 3 cevabınız doğru. Puanınız: 30")
  print("Testi geçemediniz.")
  tekrar = input("Testi tekrar denemek ister misiniz? evet/hayır")
  evet = "evet"
  hayır = "hayır"
  if tekrar == evet:
    print("Tekrardan başarılar.")
  elif tekrar == hayır:
    print("Görüşmek dileğiyle.:)") 

if puan == 40:
  print("Maalesef 6 cevabınız yanlış ve 4 cevabınız doğru. Puanınız: 40")
  print("Testi geçemediniz.")
  tekrar = input("Testi tekrar denemek ister misiniz? evet/hayır")
  evet = "evet"
  hayır = "hayır"
  if tekrar == evet:
    print("Tekrardan başarılar.")
  elif tekrar == hayır:
    print("Görüşmek dileğiyle.:)")


if puan == 50:
  print("Maalesef 5 cevabınız yanlış ve 5 cevabınız doğru. Puanınız: 50")
  print("Testi geçemediniz.")
  tekrar = input("Testi tekrar denemek ister misiniz? evet/hayır")
  evet = "evet"
  hayır = "hayır"
  if tekrar == evet:
    print("Tekrardan başarılar.")
  elif tekrar == hayır:
    print("Görüşmek dileğiyle.:)")

elif puan == 60:
  print("Puanınız: 60")
  print("Tebrikler!! Testi başarıyla geçtiniz.4 sorunuz yanlış ve 6 sorunuz doğru. Mükemmelsiniz :)")

elif puan == 70:
  print("Puanınız: 70")
  print("Tebrikler!! Testi başarıyla geçtiniz.3 sorunuz yanlış ve 7 sorunuz doğru. Mükemmelsiniz :)")

elif puan == 80:
  print("Puanınız: 80")
  print("Tebrikler!! Testi başarıyla geçtiniz.2 sorunuz yanlış ve 8 sorunuz doğru. Mükemmelsiniz :)")

elif puan == 90:
  print("Puanınız: 90")
  print("Tebrikler!! Testi başarıyla geçtiniz.1 sorunuz yanlış ve 9 sorunuz doğru. Mükemmelsiniz :)") 

elif puan == 100:
  print("Puanınız: 100")
  print("Tebrikler!! Testi başarıyla geçtiniz.0 sorunuz yanlış ve 10 sorunuz doğru. Mükemmelsiniz :)")
