# %% [markdown]
# <a href="https://colab.research.google.com/github/sevgiE/HU-BBY162-2022/blob/main/proje02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import choice



def oyunFon():
  # can sayısının belirlenmesi
  adamCan = 3

  kelimeler = ['bergamot','hamburger','çanak','balina','klima']
  secilenKelime = []
  dizilenKelime = []
  tumKelimelerBulundu = False
  sayac = 0
  tekrarOyna = True
  


  print("-------------------------\n\n\n\t\tADAM ASMACA \n\n\nLütfen zorluk derecesi giriniz (basit, orta, ileri): ")
  x = input()
  print (x)
  # Seçilen zorluğa göre kelimelerin seçilmesi
  if x == 'basit':
    for kelime in kelimeler:
      if len(kelime) <= 5:
        secilenKelime.append(kelime)
  elif x == 'orta':
    for kelime in kelimeler:
      if len(kelime) > 5 and len(kelime)<= 7:
        secilenKelime.append(kelime)
  elif x == 'ileri':
    for kelime in kelimeler:
      if len(kelime) > 7:
        secilenKelime.append(kelime)
  secim = choice(secilenKelime)

  # Seçilen kelimedeki harf sayısı kadar "_" karakterinin dizilenKelime dizisine eklenmesi ve yazdırılması
  for diz in secim:
    dizilenKelime.append("_")
  print(dizilenKelime)

  # Oyun Döngüsü
  while adamCan >0 or tekrarOyna == True : 
    
    girilenHarf = input("Lütfen bir harf giriniz: ")
    canKontrol = girilenHarf in secim
    
    if canKontrol == False:
      adamCan -=1
    
    # Oyunun durum kontrolü, eğer sayaç+1 sayısı seçilen kelimenin uzunluğuna eşitse while döngüsünden çıkar
    elif sayac+1  == len(secim):
      print("\nTebrikler! Seçilen kelime: " + secim)
      y = input("Tekrar oynamak ister misiniz?(evet, hayır):")
      if y == 'hayır':
        tekrarOyna == False
        break
      elif y == 'evet':
          oyunFon()

      
    else:
      i = 0    
      for kontrol in secim:
        if secim[i] == girilenHarf:
          dizilenKelime[i] = girilenHarf
          sayac +=1       
        i+=1
    print(dizilenKelime)
    print("\n")
    print('Kalan can: ' + str(adamCan) + '\n')
  if adamCan == 0:
    print("Kaybettiniz")
oyunDurum = True
while oyunDurum == True:
  oyunFon()
  oyunDurum = False
# Out:
# -------------------------
#
#
# 		ADAM ASMACA
#
#
# Lütfen zorluk derecesi giriniz (basit, orta, ileri):
# orta
# orta
# ['_', '_', '_', '_', '_', '_']
# Lütfen bir harf giriniz: b
# ['b', '_', '_', '_', '_', '_']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: a
# ['b', 'a', '_', '_', '_', 'a']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: l
# ['b', 'a', 'l', '_', '_', 'a']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: i
# ['b', 'a', 'l', 'i', '_', 'a']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: n
#
# Tebrikler! Seçilen kelime: balina
# Tekrar oynamak ister misiniz?(evet, hayır):a
# ['b', 'a', 'l', 'i', '_', 'a']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: n
#
# Tebrikler! Seçilen kelime: balina
# Tekrar oynamak ister misiniz?(evet, hayır):evet
# -------------------------
#
#
# 		ADAM ASMACA
#
#
# Lütfen zorluk derecesi giriniz (basit, orta, ileri):
# basit
# basit
# ['_', '_', '_', '_', '_']
# Lütfen bir harf giriniz: k
# ['_', '_', '_', '_', 'k']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: l
# ['_', '_', '_', '_', 'k']
#
#
# Kalan can: 2
#
# Lütfen bir harf giriniz: ç
# ['ç', '_', '_', '_', 'k']
#
#
# Kalan can: 2
#
# Lütfen bir harf giriniz: a
# ['ç', 'a', '_', 'a', 'k']
#
#
# Kalan can: 2
#
# Lütfen bir harf giriniz: n
#
# Tebrikler! Seçilen kelime: çanak
# Tekrar oynamak ister misiniz?(evet, hayır):a
# ['ç', 'a', '_', 'a', 'k']
#
#
# Kalan can: 2
#
# Lütfen bir harf giriniz: n
#
# Tebrikler! Seçilen kelime: çanak
# Tekrar oynamak ister misiniz?(evet, hayır):evet
# -------------------------
#
#
# 		ADAM ASMACA
#
#
# Lütfen zorluk derecesi giriniz (basit, orta, ileri):
# ileri
# ileri
# ['_', '_', '_', '_', '_', '_', '_', '_', '_']
# Lütfen bir harf giriniz: a
# ['_', 'a', '_', '_', '_', '_', '_', '_', '_']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: h
# ['h', 'a', '_', '_', '_', '_', '_', '_', '_']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: m
# ['h', 'a', 'm', '_', '_', '_', '_', '_', '_']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: b
# ['h', 'a', 'm', 'b', '_', '_', '_', '_', '_']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: u
# ['h', 'a', 'm', 'b', 'u', '_', '_', '_', '_']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: r
# ['h', 'a', 'm', 'b', 'u', 'r', '_', '_', 'r']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: g
# ['h', 'a', 'm', 'b', 'u', 'r', 'g', '_', 'r']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: r
#
# Tebrikler! Seçilen kelime: hamburger
# Tekrar oynamak ister misiniz?(evet, hayır):f
# ['h', 'a', 'm', 'b', 'u', 'r', 'g', '_', 'r']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: h
#
# Tebrikler! Seçilen kelime: hamburger
# Tekrar oynamak ister misiniz?(evet, hayır):s
# ['h', 'a', 'm', 'b', 'u', 'r', 'g', '_', 'r']
#
#
# Kalan can: 3
#
# Lütfen bir harf giriniz: k
# ['h', 'a', 'm', 'b', 'u', 'r', 'g', '_', 'r']
#
#
# Kalan can: 2
#
# Lütfen bir harf giriniz: a
#
# Tebrikler! Seçilen kelime: hamburger
# Tekrar oynamak ister misiniz?(evet, hayır):b
# ['h', 'a', 'm', 'b', 'u', 'r', 'g', '_', 'r']
#
#
# Kalan can: 2
#
# Lütfen bir harf giriniz: a
#
# Tebrikler! Seçilen kelime: hamburger
